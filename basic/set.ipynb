# %%
my_set={1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_empty_set=set()
print(my_empty_set)
print(type(my_empty_set))
# Out:
# set()
# <class 'set'>

# %%
my_set1=set([1,2,3,4,5,5])
print(my_set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(my_set1.pop())
print(my_set1)
# Out:
# 1
# {2, 3, 4, 5}

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}

# %%
set3={1,2,3,4,5,6}
set4={4,5,6}
print(set3.issuperset(set4))
print(set4.issubset(set3))
# Out:
# True
# True

# %%
mylist=[1,2,3,4,5]
print(mylist.pop())
print(mylist)
# Out:
# 5
# [1, 2, 3, 4]

# %%
L10=[1,2,2,3,3,3,4,4,4,4]
L11={}
for i in L10:
    if i in L11:
        L11[i]+=1
    else:
        L11[i]=1
print(L11)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}
