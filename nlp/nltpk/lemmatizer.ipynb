# %%
#lemmatizer is a tool that reduces words to their base or root form, known as a lemma. It is commonly used in natural language processing (NLP) tasks to improve the accuracy of text analysis by treating different forms of a word as the same entity. For example, the words "running," "ran," and "runs" would all be reduced to the lemma "run." This process helps in tasks such as text classification, sentiment analysis, and information retrieval by allowing the model to focus on the core meaning of words rather than their various inflected forms.

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ramrekhayadav/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/ramrekhayadav/nltk_data...
# True

# %%
lemmatizer.lemmatize("running", pos='v')  # Output: 'run'
# Out:
# 'run'
