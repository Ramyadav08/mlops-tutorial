# %%
#paragraph
paragraph="""I am a passionate DevOps and MLOps Engineer with hands-on experience in building scalable cloud infrastructure across AWS and GCP. I specialize in Kubernetes, Terraform, Helm, GitHub Actions, CI/CD automation, and cloud-native observability solutions. I enjoy designing secure and automated platforms that simplify deployments, improve reliability, and help teams ship faster. My experience includes implementing monitoring and logging stacks using Prometheus, Grafana, Loki, Tempo, OpenTelemetry, and SigNoz, as well as automating infrastructure, secret management, and production workflows in Kubernetes environments. I am always eager to learn new technologies, solve real-world infrastructure problems, and build systems that are efficient, resilient, and production-ready"""

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
stemmer=PorterStemmer()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ramrekhayadav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentances=nltk.sent_tokenize(paragraph)

# %%
type(sentances)
# Out:
# list

# %%
for i  in range(len(sentances)):
    words=nltk.word_tokenize(sentances[i])
    words=[stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentances[i]=' '.join(words)

# %%
sentances
# Out:
# ['passion devop mlop engin hands-on experi build scalabl cloud infrastructur across aw gcp .',
#  'special kubernet , terraform , helm , github action , ci/cd autom , cloud-n observ solut .',
#  'enjoy design secur autom platform simplifi deploy , improv reliabl , help team ship faster .',
#  'experi includ implement monitor log stack use prometheu , grafana , loki , tempo , opentelemetri , signoz , well autom infrastructur , secret manag , product workflow kubernet environ .',
#  'alway eager learn new technolog , solv real-world infrastructur problem , build system effici , resili , production-readi']

# %%
from nltk.stem import  SnowballStemmer
snowball_stemmer=SnowballStemmer('english')
sentances=nltk.sent_tokenize(paragraph)
for i in range(len(sentances)):
    words=nltk.word_tokenize(sentances[i])
    words=[snowball_stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentances[i]=' '.join(words)

# %%
sentances
# Out:
# ['i passion devop mlop engin hands-on experi build scalabl cloud infrastructur across aw gcp .',
#  'i special kubernet , terraform , helm , github action , ci/cd autom , cloud-nat observ solut .',
#  'i enjoy design secur autom platform simplifi deploy , improv reliabl , help team ship faster .',
#  'my experi includ implement monitor log stack use prometheus , grafana , loki , tempo , opentelemetri , signoz , well autom infrastructur , secret manag , product workflow kubernet environ .',
#  'i alway eager learn new technolog , solv real-world infrastructur problem , build system effici , resili , production-readi']

# %%
# lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer=WordNetLemmatizer()
sentances=nltk.sent_tokenize(paragraph)
for i in range(len(sentances)):
    words=nltk.word_tokenize(sentances[i])
    words=[lemmatizer.lemmatize(word,pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentances[i]=' '.join(words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ramrekhayadav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
sentances
# Out:
# ['I passionate DevOps MLOps Engineer hands-on experience build scalable cloud infrastructure across AWS GCP .',
#  'I specialize Kubernetes , Terraform , Helm , GitHub Actions , CI/CD automation , cloud-native observability solutions .',
#  'I enjoy design secure automate platforms simplify deployments , improve reliability , help team ship faster .',
#  'My experience include implement monitor log stack use Prometheus , Grafana , Loki , Tempo , OpenTelemetry , SigNoz , well automate infrastructure , secret management , production workflows Kubernetes environments .',
#  'I always eager learn new technologies , solve real-world infrastructure problems , build systems efficient , resilient , production-ready']
