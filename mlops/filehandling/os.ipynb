# %%
import os
os.getcwd()
# Out:
# '/Users/ramrekhayadav/mlops/python/mlops/filehandling'

# %%
os.mkdir('test_dir')

# %%
import json
data = {'name': 'Alice', 'age': 30, 'city': 'New York'}

json_string = json.dumps(data) # Convert dictionary to JSON string
print(json_string)
print(type(json_string))

parsed_data = json.loads(json_string) # Convert JSON string back to dictionary
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}
# <class 'str'>
# {'name': 'Alice', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
with open('sample.txt', 'w') as f:
    f.write("Hello, World!\n")
    f.write("This is a test file.\n")
    f.write("Goodbye, World!\n")

with open('sample.txt', 'r') as f:
    contents = f.read()
    print(contents)

os.getcwd()

# read file line by line
with open('sample.txt', 'r') as f:
    for line in f:
        print(line.strip())
# Out:
# Hello, World!
# This is a test file.
# Goodbye, World!
#
# Hello, World!
# This is a test file.
# Goodbye, World!
