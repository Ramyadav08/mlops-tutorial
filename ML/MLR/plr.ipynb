# %%
import pandas as pd    
import numpy as np          
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X=6*np.random.rand(100,1)-3
y=0.5*X**2+1.5*X+2+np.random.rand(100,1)

# %%
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Quadratic Data")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.plot(X_train,lr.predict(X_train),color='r')
plt.scatter(X_train,y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2,include_bias=True)

# %%
X_train_poly = poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)

# %%
X_test_poly
# Out:
# array([[ 1.00000000e+00,  7.38529987e-01,  5.45426541e-01],
#        [ 1.00000000e+00, -2.89851013e+00,  8.40136099e+00],
#        [ 1.00000000e+00,  1.58873974e+00,  2.52409398e+00],
#        [ 1.00000000e+00,  2.02526652e+00,  4.10170446e+00],
#        [ 1.00000000e+00,  1.02540231e+00,  1.05144990e+00],
#        [ 1.00000000e+00,  4.23427299e-01,  1.79290677e-01],
#        [ 1.00000000e+00, -4.39920941e-01,  1.93530434e-01],
#        [ 1.00000000e+00,  1.97640001e+00,  3.90615699e+00],
#        [ 1.00000000e+00, -8.55942455e-01,  7.32637487e-01],
#        [ 1.00000000e+00,  1.04702241e+00,  1.09625592e+00],
#        [ 1.00000000e+00,  1.92391098e+00,  3.70143347e+00],
#        [ 1.00000000e+00,  8.80397660e-01,  7.75100040e-01],
#        [ 1.00000000e+00,  1.94852480e+00,  3.79674890e+00],
#        [ 1.00000000e+00, -2.34688225e+00,  5.50785631e+00],
#        [ 1.00000000e+00,  1.59301362e+00,  2.53769239e+00],
#        [ 1.00000000e+00,  1.22097161e-01,  1.49077166e-02],
#        [ 1.00000000e+00, -1.22016485e+00,  1.48880226e+00],
#        [ 1.00000000e+00,  5.66906783e-02,  3.21383301e-03],
#        [ 1.00000000e+00, -9.39842370e-01,  8.83303681e-01],
#        [ 1.00000000e+00, -2.22079709e+00,  4.93193972e+00]])

# %%
lr.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,lr.predict(X_train_poly))
plt.scatter(X_train,y_train)
