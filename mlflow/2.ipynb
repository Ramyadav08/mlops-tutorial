# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-3.8.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-skinny==3.8.1 (from mlflow)
#   Using cached mlflow_skinny-3.8.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.8.1 (from mlflow)
#   Using cached mlflow_tracing-3.8.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow) (3.1.2)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow)
#   Using cached cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting huey<3,>=2.5.0 (from mlflow)
#   Using cached huey-2.5.5-py3-none-any.whl.metadata (4.8 kB)
# Collecting matplotlib<4 (from mlflow)
#   Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Requirement already satisfied: numpy<3 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow) (2.4.0)
# Requirement already satisfied: pandas<3 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow) (2.3.3)
# Collecting pyarrow<23,>=4.0.0 (from mlflow)
#   Using cached pyarrow-22.0.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.1 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting scipy<2 (from mlflow)
#   Using cached scipy-1.16.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Using cached sqlalchemy-2.0.45-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow-skinny==3.8.1->mlflow) (8.2.1)
# Collecting cloudpickle<4 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached databricks_sdk-0.76.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: fastapi<1 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow-skinny==3.8.1->mlflow) (0.116.1)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow-skinny==3.8.1->mlflow) (25.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow-skinny==3.8.1->mlflow) (2.11.7)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.8.1->mlflow)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow-skinny==3.8.1->mlflow) (4.14.1)
# Requirement already satisfied: uvicorn<1 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from mlflow-skinny==3.8.1->mlflow) (0.35.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting cffi>=2.0.0 (from cryptography<47,>=43.0.0->mlflow)
#   Using cached cffi-2.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow)
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: blinker>=1.9.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from Flask<4->mlflow) (3.1.4)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow)
#   Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow)
#   Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib<4->mlflow)
#   Using cached pillow-12.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib<4->mlflow)
#   Using cached pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas<3->mlflow) (2025.3)
# Collecting joblib>=1.3.0 (from scikit-learn<2->mlflow)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn<2->mlflow)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Using cached google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow) (0.47.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow)
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (3.10)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h11>=0.8 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow) (0.16.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ramrekhayadav/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (1.3.1)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached mlflow-3.8.1-py3-none-any.whl (9.1 MB)
# Using cached mlflow_skinny-3.8.1-py3-none-any.whl (2.5 MB)
# Using cached mlflow_tracing-3.8.1-py3-none-any.whl (1.4 MB)
# Using cached alembic-1.17.2-py3-none-any.whl (248 kB)
# Using cached cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Using cached huey-2.5.5-py3-none-any.whl (76 kB)
# Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
# Using cached pyarrow-22.0.0-cp311-cp311-macosx_12_0_arm64.whl (34.3 MB)
# Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl (8.1 MB)
# Using cached scipy-1.16.3-cp311-cp311-macosx_14_0_arm64.whl (20.9 MB)
# Using cached sqlalchemy-2.0.45-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
# Using cached cachetools-6.2.4-py3-none-any.whl (11 kB)
# Using cached cffi-2.0.0-cp311-cp311-macosx_11_0_arm64.whl (180 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached databricks_sdk-0.76.0-py3-none-any.whl (774 kB)
# Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
# Using cached gitpython-3.1.46-py3-none-any.whl (208 kB)
# Using cached graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Using cached pillow-12.1.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
# Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: huey, zipp, urllib3, threadpoolctl, sqlparse, sqlalchemy, smmap, scipy, pyyaml, python-dotenv, pyparsing, pycparser, pyasn1, pyarrow, protobuf, pillow, Mako, kiwisolver, joblib, gunicorn, graphql-core, fonttools, cycler, contourpy, cloudpickle, charset_normalizer, certifi, cachetools, scikit-learn, rsa, requests, pyasn1-modules, opentelemetry-proto, matplotlib, importlib_metadata, graphql-relay, gitdb, cffi, alembic, opentelemetry-api, graphene, google-auth, gitpython, Flask-CORS, docker, cryptography, opentelemetry-semantic-conventions, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
# Successfully installed Flask-CORS-6.0.2 Mako-1.3.10 alembic-1.17.2 cachetools-6.2.4 certifi-2025.11.12 cffi-2.0.0 charset_normalizer-3.4.4 cloudpickle-3.1.2 contourpy-1.3.3 cryptography-46.0.3 cycler-0.12.1 databricks-sdk-0.76.0 docker-7.1.0 fonttools-4.61.1 gitdb-4.0.12 gitpython-3.1.46 google-auth-2.45.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 huey-2.5.5 importlib_metadata-8.7.1 joblib-1.5.3 kiwisolver-1.4.9 matplotlib-3.10.8 mlflow-3.8.1 mlflow-skinny-3.8.1 mlflow-tracing-3.8.1 opentelemetry-api-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 pillow-12.1.0 protobuf-6.33.2 pyarrow-22.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pycparser-2.23 pyparsing-3.3.1 python-dotenv-1.2.1 pyyaml-6.0.3 requests-2.32.5 rsa-4.9.1 scikit-learn-1.8.0 scipy-1.16.3 smmap-5.0.2 sqlalchemy-2.0.45 sqlparse-0.5.5 threadpoolctl-3.6.0 urllib3-2.6.2 zipp-3.23.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
#mlflow tracking server

import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("check the local host connection!")
with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("ram",2)
# Out:
# 2026/01/02 16:56:15 INFO mlflow.tracking.fluent: Experiment with name 'check the local host connection!' does not exist. Creating a new experiment.
# 🏃 View run charming-midge-670 at: http://127.0.0.1:5000/#/experiments/1/runs/570f2824688b435bbedadaf9bf9c81da
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("ram1",2)
# Out:
# 🏃 View run languid-moth-682 at: http://127.0.0.1:5000/#/experiments/1/runs/af9ec6abad334b12857858ca6481e529
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
